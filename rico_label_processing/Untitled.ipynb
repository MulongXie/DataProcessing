# %%
import pandas as pd

# %%
class_org = pd.read_csv('rico_class_org.csv', index_col=0)

# %%
class_org['number'].sum()
# Out:
# 2883590

# %%
class_selected = class_org[class_org['number'] > 1000]
class_selected.to_csv('rico_class_select.csv')

print(len(class_selected), class_selected['number'].sum() / class_org['number'].sum())
# Out:
# 115 0.8653979934734134

# %%
class_selected
# Out:
#                                             class_name  number
# 0                          android.widget.LinearLayout  495042
# 1          android.support.v7.widget.AppCompatTextView  279746
# 2                              android.widget.TextView  271162
# 3                        android.widget.RelativeLayout  227007
# 4                             android.widget.ImageView  192384
# 5                                    android.view.View  185099
# 6                           android.widget.FrameLayout  170185
# 7         android.support.v7.widget.AppCompatImageView  135994
# 8    com.android.internal.policy.PhoneWindow$DecorView   65274
# 9                           android.widget.ImageButton   39185
# 10                               android.widget.Button   31962
# 11                          android.widget.ProgressBar   21552
# 12           android.support.v7.widget.AppCompatButton   21526
# 13      android.support.v7.widget.AppCompatImageButton   20264
# ...
