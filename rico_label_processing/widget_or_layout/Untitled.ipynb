# %%
import pandas as pd

# %%
class_all = pd.read_csv('rico_class_org.csv', index_col=0)

# %%
filter_layout = class_all['class_name'].str.contains('Layout') \
| class_all['class_name'].str.contains('PhoneWindow') \
| class_all['class_name'].str.contains('Container') \
| class_all['class_name'].str.contains('Card') \
| class_all['class_name'].str.contains('view.View') \
| class_all['class_name'].str.contains('BottomBar')

# %%
filter_widget = class_all['class_name'].str.contains('Text') \
| class_all['class_name'].str.contains('Image') \
| class_all['class_name'].str.contains('Button') \
| class_all['class_name'].str.contains('ActionManuView')

# %%
class_all[class_all['class_name'].str.contains('BottomBar')]
# Out:
#                                               class_name  number
# 244                  com.roughike.bottombar.BottomBarTab     484
# 503                      com.android.camera.ui.BottomBar     228
# 603                     com.roughike.bottombar.BottomBar     188
# 1405   com.precisosol.infinitescrollview.BottomBarIte...      75
# 2464   ru.mamba.client.v2.view.menu.bottombar.BottomB...      40
# 3647   intelgeen.rocketdial.pro.ui.TabHostBottomBar$T...      25
# 3842                  com.autoscout24.ui.views.BottomBar      24
# 4724               com.roughike.bottombar.BottomBarBadge      19
# 5000              com.cmcm.onews.ui.widget.BottomBarView      18
# 5004         net.ixxi.ratp.tourisme.widget.BottomBarView      18
# 6290                      com.waze.view.navbar.BottomBar      13
# 7565   com.aviary.android.feather.sdk.widget.AviaryBo...      11
# 8001           com.harman.jblmusicflow.main.ui.BottomBar      10
# ...

# %%
class_all[filter_layout]
# Out:
#                                               class_name  number
# 0                            android.widget.LinearLayout  661798
# 1                          android.widget.RelativeLayout  343887
# 4                             android.widget.FrameLayout  269660
# 6                                      android.view.View  204124
# 8      com.android.internal.policy.PhoneWindow$DecorView   66673
# 11          android.support.v7.widget.ContentFrameLayout   28059
# 13                    android.support.v7.widget.CardView   23863
# 17      android.support.v7.widget.FitWindowsLinearLayout   18663
# 19                android.support.v4.widget.DrawerLayout   16296
# 27                     android.support.v4.view.ViewPager   10127
# 28       android.support.design.widget.TabLayout$TabView   10055
# 31       android.support.design.widget.CoordinatorLayout    8741
# 35     com.android.internal.widget.ActionBarOverlayLa...    7583
# ...
